# %%
#first python program
print("hello")
print("kushagra")
#print built in function 
#"" what ever inside will be printed as output
print("hello , kushagra")
print(23)
print(36)
print(25+34)
# Out:
# hello
# kushagra
# hello , kushagra
# 23
# 36
# 59

# %%
#variable
name = "kush" # name is double quote
age = 23 # integer value
price = 25.99 # flaoting value
age2  = age
print(name)
print(age)
print(price)
print("My name is :", name , "," , "My age is :",age)
print(age2)
print(type(name))
print(type(price)) #this tell the type of the variable
# Out:
# kush
# 23
# 25.99
# My name is : kush , My age is : 23
# 23
# <class 'str'>
# <class 'float'>

# %%
# data type
age = 23
old = False
a = None
print(type(age))
print(type(old))
print(type(a))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# print sum problem
a = 2
b = 5
sum = a+b
print(sum)
# Out:
# 7

# %%
#Comment in python
#single line
""" 
multi line comment
 
"""
# Out:
# ' \nmulti line comment\n\n'

# %%
# # operator

# #arithmetic operator
# a = 5
# b = 2
# sum = a + b
# sub = a - b
# mul = a*b
# div = a/b
# mod = a%b
# power = a**b
# print(sum)
# print(sub)
# print(mul)
# print(div)
# print(mod)
# print(power)


# # relational /comparison operator
# a = 50
# b = 20
# print(a == b)
# print(a != b)
# print(a > b)
# print(a < b)
# print(a >= b)
# print(a <= b)

#assignment operator
# a = 20
# print(a)
# a += 5  # a = a + 5
# print(a)
# a -= 3  # a = a - 3
# print(a)
# a *= 2  # a = a * 2
# print(a)
# a /= 4  # a = a / 4
# print(a)
# a %= 3  # a = a % 3
# print(a)
# a **= 8  # a = a ** 2
# print(a)

#logical operator
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# and operator answer sahi tabhi de ga jab dono true hai
# not operator ulta answer de ga
# or operator dono mai sai ek bhi true toh true
# Out:
# False
# True
# False

# %%
# type conversion
# 1) type conversion(automatically)

a = 2
b = 4.23
print(a+b)
#float is superior value that why type conversion


#type casting
# to type cast in int int(b)
a = int("2")
a = float("4")
b = 4.25
print(a+b)
# Out:
# 6.23
# 8.25

# %%
# input 
# name = input("enter your age:")
# print("your entered" , name)
# print(type(name),name)

# int('5')
# val = int(input("enter your age:"))
# print(type(name),name)

name = input("enter your name:")
age = int(input("enter your age:"))
mark = float(input("enter your mark:"))
print("welcome" , name)
print("your age is" , age)
print("your mark is" , mark)
# Out:
# welcome kuahsgta
# your age is 34
# your mark is 99.99

# %%
#print sum taking input
a = int(input("enter you number"))
b = int(input("enter your second number"))
sum = a + b
print(sum)
# Out:
# 7

# %%
#take input of a square and print its area
a = float(input("enter the side lenght"))
area = a*a
print(area)
# Out:
# 44.89

# %%
#input two floating point number and print their average
a = float(input("enter the number"))
b = float(input("enter the number"))
avg = (a+b) / 2
print(avg)
# Out:
# 3.0

# %%
#take two input int number a and b
#print true if a is greater than or equal to b if not false
a = int(input("enter a:"))
b = int(input("enter b:"))
print(a >= b)
# Out:
# True
