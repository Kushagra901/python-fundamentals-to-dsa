# %%
#dictionary
# info = {
#     "key" : "value",
#     "name"  : "apnacollege",
#     "learning" : "python",
#     "age" : 35,
#     "is_adult" : True,
#     "subject"  : ["pythin","c++"]
# }
# print(type(info))
# info["age"]
# print(info["learning"])
# info["name"] = "kushagra"
# info["surname"] = "srivastava"
# print(info)

# null_dict = {}#null dictionary
# null_dict["name"] = "kushagra"
# print(null_dict)


#nested dictionary
# student = {
#     "name" : "rahukl",
#     "Subject" : {
#         "phy" : 45,
#         "Chem" : 98
#     } 
# }
# print(student)
# print(student["Subject"])
# print(student["Subject"]["Chem"])


# methoud in dictionary
info = {
    "key" : "value",
    "name"  : "apnacollege",
    "learning" : "python",
    "age" : 35,
    "is_adult" : True,
    "subject"  : ["pythin","c++"]
}
print(len(info))
print(list(info.keys()))
print(len(list(info.keys())))
print(info.values())
print(info.items())
print(info.get("learning"))
pair = list(info.items())
print(pair[0])

print(info["learning"])
print(info.get("learning"))


#print(info["learning2"]) #will give erroe while name change 
#after this if we print their anything after this then tnothing will be printed or done
#print(info.get("learning2")) # will give none

info.update({"city" : "varanasi"})
print(info)
new_dict = {"City" : "varansi"}
print(new_dict)
print(info)
# Out:
# 6
# ['key', 'name', 'learning', 'age', 'is_adult', 'subject']
# 6
# dict_values(['value', 'apnacollege', 'python', 35, True, ['pythin', 'c++']])
# dict_items([('key', 'value'), ('name', 'apnacollege'), ('learning', 'python'), ('age', 35), ('is_adult', True), ('subject', ['pythin', 'c++'])])
# python
# ('key', 'value')
# python
# python
# {'key': 'value', 'name': 'apnacollege', 'learning': 'python', 'age': 35, 'is_adult': True, 'subject': ['pythin', 'c++'], 'city': 'varanasi'}
# {'City': 'varansi'}
# {'key': 'value', 'name': 'apnacollege', 'learning': 'python', 'age': 35, 'is_adult': True, 'subject': ['pythin', 'c++'], 'city': 'varanasi'}
