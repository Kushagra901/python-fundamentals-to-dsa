# %%
#list
# marks = [12,3,4,5656,5765,43,234,45] #this is list
# print(type(marks))
# print(marks)
# print(marks[3])
# print(marks[2])
# print(len(marks))
# #store element of differnt type
# #(int,flaot,str) all in one
# student = ["kararn",456,213,"mumbai"]
# print(student)

# #list are mutable
# print(student[0])
# student[0] = "arjun"
# print(student)
# print(student[9])#not in range

#slicing in list(ending list is not included)
# marks = [86,57,98,54,678,98]
# print(marks[1:4])
# print(marks[-3:-1])


#list methoud'
#append
# marks  = [1,2,3,4]
# marks.append(5)
# print(marks)

#sort
# student = [2,8,9,5,6]
# list = ["ba","li","ap"]
# list.sort()
# print(list)
# student.sort()
# print(student)

#sort(reverse = True)
# student.sort(reverse = True)
# print(student)

#reverse
# marks1 = [4,5,6,2,3]
# marks1.reverse()
# print(marks1)

#insert
# marks = [1,2,4,5]
# marks.insert(3,3)
# print(marks)

# #remove(fisrt occurence)
# marks2 = [1,2,1,4,5]
# marks2.remove(1)
# print(marks2)

# #pop
# mark3 = [1,2,3,4]
# mark3.pop(2)
# print(mark3)
#square bracket
# Out:
# [1, 2, 4, 3, 5]
# [2, 1, 4, 5]
# [1, 2, 4]

# %%
#tuple
#parenthese
# mark = (1,2,3,4)
# print(mark[1])
# print(mark[3])
# print(type(mark))


#slicing
# mar = [1,2,3,4]
# print(mar[1:3])

#tuple methoud
#index
pri = [1,2,3]
print(pri.index(2))

#count
pp = [1,2,3,1,1,3,2,4,3,3]
print(pp.count(1))
# Out:
# 1
# 3

# %%
#practice question
#ask the user to enter name of thier 3 favourite movie and store them in a list
# movie1 = input("enter you first movie")
# movie2 = input("enter you second movie")
# movie3 = input("enter you third movie")
# movie_list = []
# movie_list.append(movie1)
# movie_list.append(movie2)
# movie_list.append(movie3)
# print(movie_list)
# print(type(movie_list))
# Out:
# ['fjkngv', 'dnds', 'njv']
# <class 'list'>

# %%
#plaindrome
# arr = input()
# n = len(arr)
# l = 0
# r = n - 1
# while(l < r):
#     if(arr[l] != arr[r]):
#         print("no it is not a palindrome")
#         break
#     l = l + 1
#     r = r - 1
# else:
#     print("true")
#     r = r-1


# #2nd methoud
# list1  = [1,2,1]
# list2 = [1,2,3]
# copy_list1 = list1.copy()
# copy_list1.reverse()
# if(copy_list1 == list1):
#     print("plaindrome")
# else:
#     print("not")
# Out:
# plaindrome

# %%
#count the number of student with a grade
tup = input()       
print(tup.count('a'))
# Out:
# 3

# %%
def solution(windows):
    if not windows:
        return []

    windows.sort(key=lambda x: x[0])
    merged = [[windows[0][0], windows[0][1]]]

    for start, end in windows[1:]:
        if start <= merged[-1][1]:
            merged[-1][1] = max(merged[-1][1],end)
        else:
            merged.append([start, end])

    return merged
