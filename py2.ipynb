# %%
# #string
# #creation of string
# str1 = "this is a string"
# str2 = 'this is my name'
# str3 = """this is a string"""

# "this is apna college's"

# str5 = "this is a string .\nwe are learning python"#next line
# str6 = "this is .\t my room"
# print(str5)

#operation
# str1 = "ksu"
# str2 = "9safdsgfsdghjf"
# sum = str1 + str2
# print(len(str1))
# print(sum)
# print(len(str2))

#indexing start from 0
# str = "apna college"
# ch = str[1]
# print(ch)

#slicing
# str = "apna college"
# print(str[1 : 6])
# print(str[1 : len(str)])
# print(str[2:]) #automatically understood


#negative slicing
# str1 = "kushagra"
# print(str1[-6:-1])


#string function
# str = "i am studying python"
# print(str.endswith("on"))
# str = str.capitalize()
# print(str)
# print(str.capitalize()) #only work one time
# print(str.replace("o","a"))
# print(str.replace("python","java"))
# print(str.find("o"))
# print(str.count("am"))


# practice question
# input user first name and print length
# str = input().strip()
# print(str)
# print(len(str))

# find the occurrence of "$" in a string
# str = "#@%$$%$^#$^%$#^$#5"
# print(str.count("$"))

# %%
#conditional statement
# age = 24
# # if(age >= 21):# after colen we have to give four space
# if(True):
#     print("can not vote")
#     print("can drive")

# light = "green"

# if(light == "red"):
#     print("stop")
# elif(light == "green"):
#     print("go")
# elif(light == "yellow"):
#     print("wait")
# print("end of the code")


# num = 5

# if(num > 2):
#     print("grater")
# elif(num>3):
#     print("hreates")
#for both if both will print but for elif who is true first will be printed


#else statement written only once if above statement are false then only it will give answer
#indentation is the spacing and proper spacing


# practice question
# grade of student based on the marks
# marks >=90 grade A
# 90>mark>=80,grade B
# 80>marks>=70,grade C
# 70>marks,grade D

# marks = int(input())
# if(marks >= 90):
#     print("grade a")
# elif(90>marks>=80):
#     print("grade b")
# elif(80>marks>=70):
#     print("grade c")
# elif(70>marks):
#     print("grade d")
# else:
#     print("fail")

#nesting if ke andar if
# age = 95
# if(age >= 18):
#     if(age>=80):
#         print("cannot drive")
#     else:
#         print("can drive")
# else:
#     print("cannot drice")


#pratice question
# 1)wap to enter if a number entered by the user is odd or even
# num = int(input())
# if(num % 2 == 0 ):
#     print("even")
# else:
#     print("odd")
    
# wap to find the greatest of 3 number entered by the user
# num1 = int(input())
# num2 = int(input())
# num3 = int(input())

# if(num1 > num3 and num1 > num2):
#     print("num1 is greater")
# elif(num2 > num1 and num2 > num3):
#     print("num2 is greater")
# else:
#     print("num3 is greater")
    
#program to find the multiple of 7 or not
num = int(input())
if(num % 7 == 0):
    print("multiple of 7")
else:
    print("not")
# Out:
# multiple of 7
